# %% [markdown]
# # Student Attendance Portal Using SupaBase

# %%
# !pip install supabase python-dotenv pandas pytz
# Out:
# Requirement already satisfied: supabase in /opt/anaconda3/lib/python3.11/site-packages (2.27.2)
# Requirement already satisfied: python-dotenv in /opt/anaconda3/lib/python3.11/site-packages (1.2.1)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (1.5.3)
# Requirement already satisfied: pytz in /opt/anaconda3/lib/python3.11/site-packages (2023.3.post1)
# Requirement already satisfied: realtime==2.27.2 in /opt/anaconda3/lib/python3.11/site-packages (from supabase) (2.27.2)
# Requirement already satisfied: supabase-functions==2.27.2 in /opt/anaconda3/lib/python3.11/site-packages (from supabase) (2.27.2)
# Requirement already satisfied: storage3==2.27.2 in /opt/anaconda3/lib/python3.11/site-packages (from supabase) (2.27.2)
# Requirement already satisfied: supabase-auth==2.27.2 in /opt/anaconda3/lib/python3.11/site-packages (from supabase) (2.27.2)
# Requirement already satisfied: postgrest==2.27.2 in /opt/anaconda3/lib/python3.11/site-packages (from supabase) (2.27.2)
# Requirement already satisfied: httpx<0.29,>=0.26 in /opt/anaconda3/lib/python3.11/site-packages (from supabase) (0.28.1)
# Requirement already satisfied: yarl>=1.22.0 in /opt/anaconda3/lib/python3.11/site-packages (from supabase) (1.22.0)
# Requirement already satisfied: deprecation>=2.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from postgrest==2.27.2->supabase) (2.1.0)
# Requirement already satisfied: pydantic<3.0,>=1.9 in /opt/anaconda3/lib/python3.11/site-packages (from postgrest==2.27.2->supabase) (2.12.5)
# Requirement already satisfied: typing-extensions>=4.14.0 in /opt/anaconda3/lib/python3.11/site-packages (from realtime==2.27.2->supabase) (4.15.0)
# Requirement already satisfied: websockets<16,>=11 in /opt/anaconda3/lib/python3.11/site-packages (from realtime==2.27.2->supabase) (15.0.1)
# Requirement already satisfied: pyiceberg>=0.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from storage3==2.27.2->supabase) (0.10.0)
# Requirement already satisfied: pyjwt>=2.10.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.27.2->supabase) (2.10.1)
# Requirement already satisfied: strenum>=0.4.15 in /opt/anaconda3/lib/python3.11/site-packages (from supabase-functions==2.27.2->supabase) (0.4.15)
# Requirement already satisfied: anyio in /opt/anaconda3/lib/python3.11/site-packages (from httpx<0.29,>=0.26->supabase) (4.12.0)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx<0.29,>=0.26->supabase) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx<0.29,>=0.26->supabase) (1.0.9)
# Requirement already satisfied: idna in /opt/anaconda3/lib/python3.11/site-packages (from httpx<0.29,>=0.26->supabase) (3.4)
# Requirement already satisfied: h11>=0.16 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.29,>=0.26->supabase) (0.16.0)
# Requirement already satisfied: h2<5,>=3 in /opt/anaconda3/lib/python3.11/site-packages (from httpx[http2]<0.29,>=0.26->postgrest==2.27.2->supabase) (4.3.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /opt/anaconda3/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.27.2->supabase) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /opt/anaconda3/lib/python3.11/site-packages (from h2<5,>=3->httpx[http2]<0.29,>=0.26->postgrest==2.27.2->supabase) (4.1.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0,>=1.9->postgrest==2.27.2->supabase) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0,>=1.9->postgrest==2.27.2->supabase) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic<3.0,>=1.9->postgrest==2.27.2->supabase) (0.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (1.24.4)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.11/site-packages (from deprecation>=2.1.0->postgrest==2.27.2->supabase) (25.0)
# Requirement already satisfied: cachetools<7.0,>=5.5 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (6.2.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (8.1.7)
# Requirement already satisfied: fsspec>=2023.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (2023.10.0)
# Requirement already satisfied: mmh3<6.0.0,>=4.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (5.2.0)
# Requirement already satisfied: pyparsing<4.0.0,>=3.1.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (3.3.2)
# Requirement already satisfied: pyroaring<2.0.0,>=1.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (1.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.20.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (2.32.5)
# Requirement already satisfied: rich<15.0.0,>=10.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (14.2.0)
# Requirement already satisfied: sortedcontainers==2.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (2.4.0)
# Requirement already satisfied: strictyaml<2.0.0,>=1.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (1.7.3)
# Requirement already satisfied: tenacity<10.0.0,>=8.2.3 in /opt/anaconda3/lib/python3.11/site-packages (from pyiceberg>=0.10.0->storage3==2.27.2->supabase) (9.1.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.10.0->storage3==2.27.2->supabase) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.20.0->pyiceberg>=0.10.0->storage3==2.27.2->supabase) (2.0.7)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.27.2->supabase) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.27.2->supabase) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich<15.0.0,>=10.11.0->pyiceberg>=0.10.0->storage3==2.27.2->supabase) (0.1.0)
# Requirement already satisfied: cryptography>=3.4.0 in /opt/anaconda3/lib/python3.11/site-packages (from pyjwt[crypto]>=2.10.1->supabase-auth==2.27.2->supabase) (42.0.2)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.11/site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.27.2->supabase) (1.16.0)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->supabase-auth==2.27.2->supabase) (2.21)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: multidict>=4.0 in /opt/anaconda3/lib/python3.11/site-packages (from yarl>=1.22.0->supabase) (6.0.4)
# Requirement already satisfied: propcache>=0.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from yarl>=1.22.0->supabase) (0.4.1)

# %%
import os
from datetime import datetime
import pytz # for timezone handling
import pandas as pd
from supabase import create_client, Client
from dotenv import load_dotenv

# %% [markdown]
# ### Load Environmental Variables and Create Supabase Client

# %%
import os
from supabase import create_client, Client

#Read the credentials from .env file
load_dotenv()

SUPABASE_URL = os.environ.get("SUPABASE_URL")
SUPABASE_KEY = os.environ.get("SUPABASE_KEY")
supabase: Client = create_client(SUPABASE_URL, SUPABASE_KEY)

# %%
#Helper function to get current time in EST timezone
def get_current_est_time():
    est = pytz.timezone('America/New_York')
    return datetime.now(est)

print("Current EST Time:", get_current_est_time())
# Out:
# Current EST Time: 2026-01-28 19:36:53.515957-05:00

# %% [markdown]
# ## Create Classroom in Supabase
# ##### Key features: 1. Prevents duplicate class creation; 2. Adds default code and attendance limit;  3. Shows database insertion

# %%
def create_classroom(class_name, code="1234", daily_limit=25):
    existing=(supabase.table("classroom_settings").select("*").eq("class_name", class_name).execute().data)
    if existing:
        return f"Classroom with name {class_name} already exists."
    
    supabase.table("classroom_settings").insert({
        "class_name": class_name,
        "code": code,
        "daily_limit": daily_limit,
        "is_open" : True
    }).execute()
    return f"Classroom {class_name} created successfully."

create_classroom("FE524", "PromptEng", 26)
# Out:
# 'Classroom with name FE524 already exists.'

# %% [markdown]
# ## Add Students to Roll Map
# ##### Key features: 1. Prevents duplicate roll numbers; 2. Writes to roll_map table

# %%
def add_students(class_name, roll_number, name):
    existing = (supabase.table("roll_map").select("*").eq("roll_number", roll_number).eq("class_name", class_name).execute().data)
    if existing:
        return f"Student with roll number {roll_number} already exists in class {class_name}."
    
    supabase.table("roll_map").insert({
        "class_name": class_name,
        "roll_number": roll_number,
        "name": name
    }).execute()
    return f"Student {name} with roll number {roll_number} added to class {class_name}."    

add_students("CS556", "004", "Nisha")
# Out:
# 'Student with roll number 004 already exists in class CS556.'

# %% [markdown]
# ## Mark Attendance
# ##### Key features: 1. Checks correct code; 2. Roll number exists; 3. Attendance not marked already; 4. Daily limit not exceeded

# %%
def mark_attendance(class_name, roll_number, code):
    today = get_current_est_time().date().isoformat()

    # 1️⃣ Validate class + code safely
    settings_resp = (
        supabase.table("classroom_settings")
        .select("daily_limit")
        .eq("class_name", class_name)
        .eq("code", code)
        .execute()
    )

    if not settings_resp.data:
        return "Invalid class name or code."

    daily_limit = settings_resp.data[0]["daily_limit"]

    # 2️⃣ Prevent duplicate attendance
    existing = (
        supabase.table("attendance")
        .select("roll_number")
        .eq("class_name", class_name)
        .eq("roll_number", roll_number)
        .eq("date", today)
        .execute()
        .data
    )

    if existing:
        return f"Attendance already marked for roll number {roll_number} in class {class_name} today."

    # 3️⃣ Enforce daily attendance limit
    count_today = (
        supabase.table("attendance")
        .select("roll_number", count="exact")
        .eq("class_name", class_name)
        .eq("date", today)
        .execute()
        .count
    )

    if count_today >= daily_limit:
        return f"Daily attendance limit reached for class {class_name}."

    # 4️⃣ Validate student roll number
    student_resp = (
        supabase.table("roll_map")
        .select("name")
        .eq("class_name", class_name)
        .eq("roll_number", roll_number)
        .execute()
    )

    if not student_resp.data:
        return f"Roll number {roll_number} not found in class {class_name}."

    name = student_resp.data[0]["name"]

    # 5️⃣ Insert attendance
    supabase.table("attendance").insert({
        "class_name": class_name,
        "roll_number": roll_number,
        "name": name,
        "date": today
    }).execute()

    return f"Attendance marked for {name} (Roll No: {roll_number}) in class {class_name}."


print(mark_attendance("CS559", "001", "FundaML"))
print(mark_attendance("CS556", "004", "MathML"))
# Out:
# Attendance already marked for roll number 001 in class CS559 today.
# Attendance already marked for roll number 004 in class CS556 today.

# %% [markdown]
# ## Show Attendance Matrix
# ##### Key features: 1. Rows -> Students; 2. Columns -> dates; 3. Values -> P/A; 4. Basic Analytics

# %%
def attendance_matrix(class_name):
    records =(
        supabase.table("attendance")
        .select("*")
        .eq("class_name", class_name)
        .order("date", desc=True)
        .execute()
        .data
    )
    
    if not records:
        return f"No attendance records found for class {class_name}."   
    
    df = pd.DataFrame(records)
    df["status"] ="P"
    
    pivot_df = df.pivot_table(index=["roll_number", "name"], columns="date", values="status", fill_value="A", aggfunc='first').reset_index()
    
    return pivot_df
